# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# **To import train data**

# %%
data = []
with open('/kaggle/input/genre-classification-dataset-imdb/Genre Classification Dataset/train_data.txt', 'r', encoding='utf-8') as file:
    for line in file:
        _, _, genre, description = line.strip().split(' ::: ')
        data.append({'genre': genre, 'description': description})

df1 = pd.DataFrame(data)

X_train = df['description']
y_train = df['genre']

df1
# Out:
#              genre                                        description
# 0            drama  Listening in to a conversation between his doc...
# 1         thriller  A brother and sister with a past incestuous re...
# 2            adult  As the bus empties the students for their fiel...
# 3            drama  To help their unemployed father make ends meet...
# 4            drama  The film's title refers not only to the un-rec...
# ...            ...                                                ...
# 54209       comedy  This short-lived NBC live sitcom centered on B...
# 54210       horror  The NEXT Generation of EXPLOITATION. The siste...
# 54211  documentary  Ze bestaan echt, is a stand-up comedy about gr...
# 54212       comedy  Walter and Vivian live in the country and have...
# 54213      history  On Labor Day Weekend, 1935, the most intense h...
#
# [54214 rows x 2 columns]

# %% [markdown]
# **To import test data**

# %%
data = []
with open('/kaggle/input/genre-classification-dataset-imdb/Genre Classification Dataset/test_data_solution.txt', 'r', encoding='utf-8') as file:
    for line in file:
        _, _, genre, description = line.strip().split(' ::: ')
        data.append({'genre': genre, 'description': description})

df2 = pd.DataFrame(data)

X_test = df['description']
y_test = df['genre']

df2
# Out:
#              genre                                        description
# 0         thriller  L.R. Brane loves his life - his car, his apart...
# 1           comedy  Spain, March 1964: Quico is a very naughty chi...
# 2      documentary  One year in the life of Albin and his family o...
# 3            drama  His father has died, he hasn't spoken with his...
# 4            drama  Before he was known internationally as a marti...
# ...            ...                                                ...
# 54195       horror  Covering multiple genres, Tales of Light & Dar...
# 54196      western  As Alice and Cora Munro attempt to find their ...
# 54197        adult  A movie 169 years in the making. Oliver Twist,...
# 54198        drama  Popular, but mysterious rock D.J Mike Mallard ...
# 54199        drama  Curitiba is a city in movement, with rhythms a...
#
# [54200 rows x 2 columns]

# %% [markdown]
# # **Genre Classification model**

# %%
# Create TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')

# Transform the text data into TF-IDF features
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# Initialize and train the Multinomial Naive Bayes classifier
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_tfidf, y_train)

# Make predictions on the test set
y_pred = nb_classifier.predict(X_test_tfidf)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Display classification report for detailed evaluation
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.55
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#       action       0.69      0.15      0.25      1315
#        adult       0.75      0.10      0.18       590
#    adventure       0.76      0.09      0.16       775
#    animation       1.00      0.01      0.02       498
#    biography       0.00      0.00      0.00       265
# ...
